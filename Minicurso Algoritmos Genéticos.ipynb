# %% [markdown]
# # Minicurso de Algoritmos Genéticos - AutomataIF
# ---
# ## Prof. Ms. Petrônio Cândido
# petronio.candido@gmail.com / petronio.candido@ifnmg.edu.br
# ### IFNMG - Campus Januária

# %%
# Importações comuns 

import numpy as np # biblioteca para processamento numérico
import matplotlib.pyplot as plt # biblioteca para geração de gráficos
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Representa um indivíduo da população
class Individuo(object):
    
    # Método construtor
    def __init__(self, numero_cromossomos):
        self.genotipo = np.random.randint(0,2,numero_cromossomos)    # gera um array de [0,1] aleários 
        self.aptidao = 0  
        self.valido = False

# %%
# Classe que implementa o algoritmo genérico
class AlgoritmoGenetico(object):
    
    # Método construtor
    def __init__(self, **kwargs):
        
        # o número de indivíduos da população
        self.populacao_tamanho = kwargs.get('populacao_tamanho', 100)
        
        # a quantidade de cromossomos de cada indivíduo
        self.numero_cromossomos = kwargs.get('numero_cromossomos', 50)
        
        # a quantidade de vezes que o ciclo evolutivo será repetido
        self.quantidade_geracoes = kwargs.get('quantidade_geracoes', 500)
        
        # % da população que será selecionada para a próxima geração
        self.taxa_selecao = kwargs.get('taxa_selecao', .5)
        
        # probabilidade do indivíduo mais apto ser escolhido durante a seleção
        self.probabilidade_selecao = kwargs.get('probabilidade_selecao', .8)
        
        # % da população que será gerada através de cruzamento
        self.taxa_cruzamento = kwargs.get('taxa_selecao', .5)
        
        # % da população que poderá sofrer mutação 
        self.taxa_mutacao = kwargs.get('taxa_selecao', .05)
        
        # a população é uma lista(array) de indivíduos
        self.populacao = [] 
        
        
    def executar(self):
        
        self.inicializar_populacao()
        
        geracoes = 0
        
        while geracoes < self.quantidade_geracoes:
            
            geracoes += 1
            
            aptidao_media = self.calcular_aptidao()
        
            self.populacao = self.selecao()
            
            populacao_filhos = self.cruzamento()
            
            self.mutacao(populacao_filhos)
            
            self.populacao.extend(populacao_filhos)
            
            print("Geração:",geracoes," Aptidão média:", aptidao_media)
    
    
    # Transforma um genótico em uma solução do problema e retorna sua aptidão
    def fenotipo(self, genotipo):
        pass
    
    # Verifica se a solução atende a todos os requisitos
    def viavel(self, genotipo):
        pass
        
    # Cria os indivíduos da primeira geração
    def inicializar_populacao(self):
        self.populacao = [ Individuo(self.numero_cromossomos) for k in np.arange(0, self.populacao_tamanho)]
    
    
    def calcular_aptidao(self):
        aptidao_media = 0
        for individuo in self.populacao:
            individuo.aptidao = self.fenotipo(individuo.genotipo)
            individuo.valido = self.viavel(individuo.genotipo)
            aptidao_media += individuo.aptidao
            
        return aptidao_media / self.populacao_tamanho
    
    def selecao(self):
        
        #calcula a quantidade de indivíduos que será selecionada
        quantidade_selecionados = self.populacao_tamanho * self.taxa_selecao
        
        nova_populacao = []
        
        #repete a seleção para quantidade_selecionados
        for i in np.arange(0,quantidade_selecionados):
        
            #escolhe dois indivíduos aleatoriamente dentro da população
            a, b = random.randint(0, self.populacao_tamanho, 2)
            
            #verifica quem é o mais apto
            mais_apto = self.populacao[a] if self.populacao[a].aptidao > self.populacao[b].aptidao else self.populacao[b]
            menos_apto = self.populacao[b] if self.populacao[b].aptidao < self.populacao[a].aptidao else self.populacao[a]
            
            #gera uma número aleatório entre 0 e 1 que será a probabilidade do mais apto ser escolhido
            probabilidade = random.uniform(0,1)

            if probabilidade <= self.probabilidade_selecao:
                nova_populacao.append(mais_apto)
            else:
                nova_populacao.append(menos_apto)
                
        return nova_populacao
    
    def cruzamento(self):
        #calcula a quantidade de indivíduos que será selecionada
        quantidade_cruzamento = self.populacao_tamanho * self.taxa_cruzamento
        
        ponto_cruzamento = self.numero_cromossomos // 2
                
        nova_populacao = []
        
        #repete a operação para quantidade_cruzamento
        for i in np.arange(0,quantidade_cruzamento):
            
            #escolhe dois indivíduos aleatoriamente dentro da população
            a, b = random.randint(0, len(self.populacao)-1, 2)

            novo_individuo = Individuo(self.numero_cromossomos)

            novo_individuo.genotipo[0:ponto_cruzamento] = self.populacao[a].genotipo[0:ponto_cruzamento]
            novo_individuo.genotipo[ponto_cruzamento:] = self.populacao[b].genotipo[ponto_cruzamento:]
            
            nova_populacao.append(novo_individuo)
            
        return nova_populacao
            
        
    def mutacao(self, populacao):
        #calcula a quantidade de indivíduos que sofrerá mutação
        quantidade_mutacoes = len(populacao) * self.taxa_mutacao
        
         #repete a operação para quantidade_cruzamento
        for i in np.arange(0, quantidade_mutacoes):
        
            #escolhe um indivíduo aleatoriamente dentro da população
            ind = random.randint(0, len(populacao))
            
            #escolhe um cromossomo aleatoriamente dentro da população
            cro = random.randint(0, self.numero_cromossomos)
            
            valor = populacao[ind].genotipo[cro]
            
            populacao[ind].genotipo[cro] = 1 if valor == 0 else 0

# %%
items = []
items.append({ 'descricao': "Lanterna", 'peso': 3, 'volume':10, 'utilidade': 15 })
items.append({ 'descricao': "Canivete Suíço", 'peso': 3, 'volume':1, 'utilidade': 10 })
items.append({ 'descricao': "Jaca", 'peso': 30, 'volume':50, 'utilidade': 3 })
items.append({ 'descricao': "Panela", 'peso': 5, 'volume':30, 'utilidade': 15 })
items.append({ 'descricao': "Carne", 'peso': 10, 'volume':15, 'utilidade': 20 })
items.append({ 'descricao': "Arroz", 'peso': 7, 'volume':10, 'utilidade': 20 })
items.append({ 'descricao': "Feijão", 'peso': 8, 'volume':10, 'utilidade': 20 })
items.append({ 'descricao': "Cerveja", 'peso': 15, 'volume':25, 'utilidade': 8 })
items.append({ 'descricao': "Mapa", 'peso': 1, 'volume':1, 'utilidade': 15 })
items.append({ 'descricao': "Celular", 'peso': 3, 'volume':5, 'utilidade': 9 })
items.append({ 'descricao': "Barraca", 'peso': 8, 'volume':50, 'utilidade': 60 })
items.append({ 'descricao': "Cobertor", 'peso': 8, 'volume':15, 'utilidade': 25 })
items.append({ 'descricao': "Jornal", 'peso': 3, 'volume':5, 'utilidade': 5 })
items.append({ 'descricao': "Papel Higiênico", 'peso': 2, 'volume':10, 'utilidade': 14 })
items.append({ 'descricao': "Carvão", 'peso': 8, 'volume':20, 'utilidade': 15 })
items.append({ 'descricao': "Repelente", 'peso': 2, 'volume':1, 'utilidade': 5 })
items.append({ 'descricao': "Vara de Pescar", 'peso': 3, 'volume':10, 'utilidade': 2 })
items.append({ 'descricao': "Pente", 'peso': 1, 'volume':1, 'utilidade': 1 })
items.append({ 'descricao': "Espelho", 'peso': 1, 'volume':5, 'utilidade': 1 })
items.append({ 'descricao': "Sabão", 'peso': 2, 'volume':5, 'utilidade': 7 })
items.append({ 'descricao': "Xampu", 'peso': 4, 'volume':5, 'utilidade': 5 })
items.append({ 'descricao': "Luvas", 'peso': 1, 'volume':1, 'utilidade': 2 })
items.append({ 'descricao': "Violão", 'peso': 15, 'volume':70, 'utilidade': 4 })
items.append({ 'descricao': "Fósforo", 'peso': 1, 'volume':1, 'utilidade': 7 })
items.append({ 'descricao': "Isqueiro", 'peso': 1, 'volume':1, 'utilidade': 9 })
items.append({ 'descricao': "Bússola", 'peso': 2, 'volume':1, 'utilidade': 14 })
items.append({ 'descricao': "Roupa", 'peso': 5, 'volume':15, 'utilidade': 28 })
items.append({ 'descricao': "Sapatos", 'peso': 3, 'volume':10, 'utilidade': 11 })
items.append({ 'descricao': "Protetor Solar", 'peso': 2, 'volume':1, 'utilidade': 6 })
items.append({ 'descricao': "Pratos", 'peso': 5, 'volume':10, 'utilidade': 12 })
items.append({ 'descricao': "Colheres", 'peso': 1, 'volume':1, 'utilidade': 8 })
items.append({ 'descricao': "Facas", 'peso': 1, 'volume':1, 'utilidade': 13 })
items.append({ 'descricao': "Binóculos", 'peso': 5, 'volume':10, 'utilidade': 3 })
items.append({ 'descricao': "GPS", 'peso': 5, 'volume':5, 'utilidade': 20 })
items.append({ 'descricao': "Notebook", 'peso': 15, 'volume':25, 'utilidade': 5 })
items.append({ 'descricao': "Som", 'peso': 16, 'volume':40, 'utilidade': 8 })
items.append({ 'descricao': "Livro", 'peso': 3, 'volume':20, 'utilidade': 3 })
items.append({ 'descricao': "Corda", 'peso': 5, 'volume':30, 'utilidade': 15 })
items.append({ 'descricao': "Lixa Unha", 'peso': 1, 'volume':1, 'utilidade': 1 })
items.append({ 'descricao': "Esmalte", 'peso': 1, 'volume':1, 'utilidade': 1 })
items.append({ 'descricao': "Alicate", 'peso': 2, 'volume':2, 'utilidade': 8 })
items.append({ 'descricao': "Machado", 'peso': 15, 'volume':20, 'utilidade': 50 })
items.append({ 'descricao': "Linha", 'peso': 1, 'volume':1, 'utilidade': 1 })
items.append({ 'descricao': "Agulha", 'peso': 1, 'volume':0, 'utilidade': 1 })
items.append({ 'descricao': "Band Aid", 'peso': 1, 'volume':1, 'utilidade': 12 })
items.append({ 'descricao': "Mertiolate", 'peso': 1, 'volume':1, 'utilidade': 11 })
items.append({ 'descricao': "Gaze", 'peso': 1, 'volume':2, 'utilidade': 13 })
items.append({ 'descricao': "Perfume", 'peso': 1, 'volume':5, 'utilidade': 1 })
items.append({ 'descricao': "Leite", 'peso': 4, 'volume':10, 'utilidade': 10 })
items.append({ 'descricao': "Biscoitos", 'peso': 4, 'volume':10, 'utilidade': 10 })
items.append({ 'descricao': "Sucrilhos", 'peso': 3, 'volume':15, 'utilidade': 7 })
items.append({ 'descricao': "Bombons", 'peso': 3, 'volume':10, 'utilidade': 5 })
items.append({ 'descricao': "Meias", 'peso': 1, 'volume':5, 'utilidade': 2 })
items.append({ 'descricao': "Chapeu", 'peso': 3, 'volume':10, 'utilidade': 7 })
items.append({ 'descricao': "Estilingue", 'peso': 1, 'volume':5, 'utilidade': 4 })
items.append({ 'descricao': "Martelo", 'peso': 6, 'volume':15, 'utilidade': 12 })
items.append({ 'descricao': "Arame", 'peso': 6, 'volume':5, 'utilidade': 15 })

# %%
class ProblemaDaMochila(AlgoritmoGenetico):
    
    def __init__(self, capacidade, itens, **kwargs):
        super(ProblemaDaMochila, self).__init__(**kwargs)
        self.itens = itens
        self.capacidade = capacidade
        
    def fenotipo(self, genotipo):
        peso = 0
        utilidade = 0
        volume = 0
        for i in np.arange(0, self.numero_cromossomos):
            peso += self.itens[i]['peso'] * genotipo[i]
            utilidade += self.itens[i]['utilidade'] * genotipo[i]
            volume += self.itens[i]['volume'] * genotipo[i]
            
        excesso_volume = 0 
        
        if volume > self.capacidade:
            excesso_volume = volume - self.capacidade
            
        return (utilidade - peso) - 10 * excesso_volume
    
    def factivel(self, genotipo):
        volume = 0
        for i in np.arange(0, self.numero_cromossomos):
            volume += self.itens[i]['volume'] * genotipo[i]
            
        return volume <= self.capacidade
    
    def imprime(self, individuo):
        lista = ""
        peso = 0
        utilidade = 0
        volume = 0
        for i in np.arange(0, self.numero_cromossomos):
            if individuo.genotipo[i] == 1:
                lista += self.itens[i]['descricao'] + ", "
                peso += self.itens[i]['peso']
                utilidade += self.itens[i]['utilidade'] 
                volume += self.itens[i]['volume'] 
                
        print("Itens: " + lista)
        print("Peso: ", peso)
        print("Volume: ", volume)
        print("Utilidae: ", utilidade)
        
    
    def melhor(self):
        self.populacao = sorted(self.populacao, key=lambda x: x.aptidao, reverse=True)
        
        self.imprime(self.populacao[0])

# %%
ag = ProblemaDaMochila(capacidade=30, itens=items)
ag.executar()
ag.melhor()
# Out:
# Geração: 1  Aptidão média: -2422.58
# Geração: 2  Aptidão média: -2136.97
# Geração: 3  Aptidão média: -1799.72
# Geração: 4  Aptidão média: -1721.13
# Geração: 5  Aptidão média: -1485.32
# Geração: 6  Aptidão média: -1301.37
# Geração: 7  Aptidão média: -1192.03
# Geração: 8  Aptidão média: -1148.63
# Geração: 9  Aptidão média: -1007.36
# Geração: 10  Aptidão média: -980.46
# Geração: 11  Aptidão média: -933.93
# Geração: 12  Aptidão média: -878.89
# Geração: 13  Aptidão média: -788.74
# Geração: 14  Aptidão média: -738.29
# Geração: 15  Aptidão média: -660.93
# Geração: 16  Aptidão média: -629.96
# Geração: 17  Aptidão média: -551.83
# Geração: 18  Aptidão média: -536.94
# Geração: 19  Aptidão média: -524.44
# Geração: 20  Aptidão média: -522.45
# Geração: 21  Aptidão média: -509.39
# Geração: 22  Aptidão média: -503.68
# Geração: 23  Aptidão média: -490.95
# Geração: 24  Aptidão média: -474.94
# Geração: 25  Aptidão média: -461.98
# Geração: 26  Aptidão média: -458.03
# Geração: 27  Aptidão média: -444.56
# Geração: 28  Aptidão média: -436.74
# Geração: 29  Aptidão média: -431.63
# Geração: 30  Aptidão média: -421.81
# Geração: 31  Aptidão média: -423.65
# Geração: 32  Aptidão média: -432.9
# Geração: 33  Aptidão média: -429.34
# Geração: 34  Aptidão média: -434.58
# Geração: 35  Aptidão média: -421.6
# Geração: 36  Aptidão média: -422.28
# Geração: 37  Aptidão média: -423.45
# Geração: 38  Aptidão média: -421.61
# Geração: 39  Aptidão média: -383.32
# Geração: 40  Aptidão média: -374.26
# Geração: 41  Aptidão média: -340.78
# Geração: 42  Aptidão média: -333.18
# Geração: 43  Aptidão média: -323.81
# Geração: 44  Aptidão média: -276.16
# Geração: 45  Aptidão média: -268.73
# Geração: 46  Aptidão média: -237.73
# Geração: 47  Aptidão média: -241.35
# Geração: 48  Aptidão média: -220.58
# Geração: 49  Aptidão média: -209.04
# Geração: 50  Aptidão média: -202.6
# Geração: 51  Aptidão média: -192.96
# Geração: 52  Aptidão média: -173.33
# Geração: 53  Aptidão média: -157.78
# Geração: 54  Aptidão média: -137.45
# Geração: 55  Aptidão média: -131.85
# Geração: 56  Aptidão média: -132.4
# Geração: 57  Aptidão média: -101.25
# Geração: 58  Aptidão média: -83.82
# Geração: 59  Aptidão média: -66.1
# Geração: 60  Aptidão média: -51.56
# Geração: 61  Aptidão média: -46.37
# Geração: 62  Aptidão média: -50.76
# Geração: 63  Aptidão média: -48.8
# Geração: 64  Aptidão média: -45.05
# Geração: 65  Aptidão média: -55.82
# Geração: 66  Aptidão média: -47.54
# Geração: 67  Aptidão média: -44.75
# Geração: 68  Aptidão média: -43.83
# Geração: 69  Aptidão média: -46.72
# Geração: 70  Aptidão média: -53.02
# Geração: 71  Aptidão média: -42.53
# Geração: 72  Aptidão média: -40.63
# Geração: 73  Aptidão média: -43.22
# Geração: 74  Aptidão média: -35.33
# Geração: 75  Aptidão média: -26.49
# Geração: 76  Aptidão média: -21.61
# Geração: 77  Aptidão média: -12.48
# Geração: 78  Aptidão média: -5.54
# Geração: 79  Aptidão média: 2.01
# Geração: 80  Aptidão média: 8.93
# Geração: 81  Aptidão média: 5.42
# Geração: 82  Aptidão média: 14.35
# Geração: 83  Aptidão média: 21.39
# Geração: 84  Aptidão média: 27.62
# Geração: 85  Aptidão média: 30.32
# Geração: 86  Aptidão média: 28.11
# Geração: 87  Aptidão média: 31.79
# Geração: 88  Aptidão média: 30.65
# Geração: 89  Aptidão média: 34.79
# Geração: 90  Aptidão média: 37.14
# Geração: 91  Aptidão média: 37.85
# Geração: 92  Aptidão média: 41.83
# Geração: 93  Aptidão média: 40.87
# Geração: 94  Aptidão média: 45.03
# Geração: 95  Aptidão média: 47.62
# Geração: 96  Aptidão média: 46.71
# Geração: 97  Aptidão média: 53.61
# Geração: 98  Aptidão média: 53.21
# Geração: 99  Aptidão média: 53.47
# Geração: 100  Aptidão média: 54.69
# Geração: 101  Aptidão média: 48.57
# Geração: 102  Aptidão média: 53.11
# Geração: 103  Aptidão média: 51.18
# Geração: 104  Aptidão média: 54.93
# Geração: 105  Aptidão média: 51.57
# Geração: 106  Aptidão média: 50.93
# Geração: 107  Aptidão média: 56.48
# Geração: 108  Aptidão média: 53.84
# Geração: 109  Aptidão média: 54.53
# Geração: 110  Aptidão média: 56.84
# Geração: 111  Aptidão média: 61.38
# Geração: 112  Aptidão média: 55.0
# Geração: 113  Aptidão média: 55.22
# Geração: 114  Aptidão média: 65.27
# Geração: 115  Aptidão média: 62.17
# Geração: 116  Aptidão média: 58.92
# Geração: 117  Aptidão média: 68.0
# Geração: 118  Aptidão média: 68.47
# Geração: 119  Aptidão média: 67.38
# Geração: 120  Aptidão média: 66.31
# Geração: 121  Aptidão média: 63.62
# Geração: 122  Aptidão média: 58.47
# Geração: 123  Aptidão média: 61.64
# Geração: 124  Aptidão média: 67.37
# Geração: 125  Aptidão média: 63.95
# Geração: 126  Aptidão média: 68.32
# Geração: 127  Aptidão média: 61.96
# Geração: 128  Aptidão média: 66.03
# Geração: 129  Aptidão média: 57.1
# Geração: 130  Aptidão média: 59.35
# Geração: 131  Aptidão média: 68.75
# Geração: 132  Aptidão média: 67.79
# Geração: 133  Aptidão média: 70.47
# Geração: 134  Aptidão média: 64.04
# Geração: 135  Aptidão média: 69.93
# Geração: 136  Aptidão média: 69.09
# Geração: 137  Aptidão média: 71.77
# Geração: 138  Aptidão média: 71.7
# Geração: 139  Aptidão média: 70.13
# Geração: 140  Aptidão média: 66.52
# Geração: 141  Aptidão média: 62.17
# Geração: 142  Aptidão média: 72.86
# Geração: 143  Aptidão média: 74.53
# Geração: 144  Aptidão média: 72.92
# Geração: 145  Aptidão média: 64.46
# Geração: 146  Aptidão média: 72.47
# Geração: 147  Aptidão média: 72.3
# Geração: 148  Aptidão média: 74.59
# Geração: 149  Aptidão média: 75.48
# Geração: 150  Aptidão média: 73.83
# Geração: 151  Aptidão média: 72.64
# Geração: 152  Aptidão média: 77.11
# Geração: 153  Aptidão média: 71.72
# Geração: 154  Aptidão média: 73.75
# Geração: 155  Aptidão média: 79.29
# Geração: 156  Aptidão média: 76.79
# Geração: 157  Aptidão média: 64.76
# Geração: 158  Aptidão média: 68.49
# Geração: 159  Aptidão média: 58.83
# Geração: 160  Aptidão média: 80.94
# Geração: 161  Aptidão média: 80.57
# Geração: 162  Aptidão média: 76.3
# Geração: 163  Aptidão média: 75.05
# Geração: 164  Aptidão média: 78.95
# Geração: 165  Aptidão média: 81.6
# Geração: 166  Aptidão média: 80.64
# Geração: 167  Aptidão média: 82.12
# Geração: 168  Aptidão média: 81.96
# Geração: 169  Aptidão média: 80.01
# Geração: 170  Aptidão média: 79.26
# Geração: 171  Aptidão média: 78.89
# Geração: 172  Aptidão média: 84.03
# Geração: 173  Aptidão média: 84.81
# Geração: 174  Aptidão média: 83.43
# Geração: 175  Aptidão média: 77.44
# Geração: 176  Aptidão média: 60.71
# Geração: 177  Aptidão média: 47.47
# Geração: 178  Aptidão média: 45.54
# Geração: 179  Aptidão média: 73.35
# Geração: 180  Aptidão média: 82.03
# Geração: 181  Aptidão média: 82.06
# Geração: 182  Aptidão média: 81.6
# Geração: 183  Aptidão média: 81.35
# Geração: 184  Aptidão média: 81.66
# Geração: 185  Aptidão média: 80.58
# Geração: 186  Aptidão média: 80.78
# Geração: 187  Aptidão média: 80.87
# Geração: 188  Aptidão média: 82.17
# Geração: 189  Aptidão média: 81.39
# Geração: 190  Aptidão média: 82.87
# Geração: 191  Aptidão média: 83.54
# Geração: 192  Aptidão média: 81.98
# Geração: 193  Aptidão média: 82.8
# Geração: 194  Aptidão média: 81.34
# Geração: 195  Aptidão média: 80.25
# Geração: 196  Aptidão média: 81.4
# Geração: 197  Aptidão média: 84.0
# Geração: 198  Aptidão média: 84.28
# Geração: 199  Aptidão média: 80.89
# Geração: 200  Aptidão média: 77.28
# Geração: 201  Aptidão média: 76.52
# Geração: 202  Aptidão média: 76.64
# Geração: 203  Aptidão média: 81.17
# Geração: 204  Aptidão média: 83.23
# Geração: 205  Aptidão média: 83.93
# Geração: 206  Aptidão média: 84.86
# Geração: 207  Aptidão média: 80.6
# Geração: 208  Aptidão média: 53.94
# Geração: 209  Aptidão média: 71.71
# Geração: 210  Aptidão média: 78.08
# Geração: 211  Aptidão média: 76.78
# Geração: 212  Aptidão média: 83.57
# Geração: 213  Aptidão média: 81.62
# Geração: 214  Aptidão média: 84.52
# Geração: 215  Aptidão média: 80.93
# Geração: 216  Aptidão média: 80.91
# Geração: 217  Aptidão média: 80.37
# Geração: 218  Aptidão média: 74.4
# Geração: 219  Aptidão média: 80.97
# Geração: 220  Aptidão média: 72.03
# Geração: 221  Aptidão média: 82.64
# Geração: 222  Aptidão média: 84.88
# Geração: 223  Aptidão média: 83.17
# Geração: 224  Aptidão média: 82.88
# Geração: 225  Aptidão média: 80.62
# Geração: 226  Aptidão média: 80.3
# Geração: 227  Aptidão média: 81.81
# Geração: 228  Aptidão média: 83.69
# Geração: 229  Aptidão média: 80.89
# Geração: 230  Aptidão média: 78.18
# Geração: 231  Aptidão média: 78.54
# Geração: 232  Aptidão média: 83.42
# Geração: 233  Aptidão média: 83.52
# Geração: 234  Aptidão média: 79.06
# Geração: 235  Aptidão média: 82.42
# Geração: 236  Aptidão média: 80.9
# Geração: 237  Aptidão média: 79.98
# Geração: 238  Aptidão média: 79.32
# Geração: 239  Aptidão média: 78.81
# Geração: 240  Aptidão média: 81.56
# Geração: 241  Aptidão média: 77.02
# Geração: 242  Aptidão média: 71.11
# Geração: 243  Aptidão média: 60.29
# Geração: 244  Aptidão média: 50.83
# Geração: 245  Aptidão média: 67.4
# Geração: 246  Aptidão média: 79.73
# Geração: 247  Aptidão média: 84.53
# Geração: 248  Aptidão média: 83.16
# Geração: 249  Aptidão média: 76.61
# Geração: 250  Aptidão média: 81.03
# Geração: 251  Aptidão média: 83.45
# Geração: 252  Aptidão média: 86.11
# Geração: 253  Aptidão média: 86.31
# Geração: 254  Aptidão média: 83.28
# Geração: 255  Aptidão média: 76.62
# Geração: 256  Aptidão média: 83.66
# Geração: 257  Aptidão média: 89.4
# Geração: 258  Aptidão média: 89.27
# Geração: 259  Aptidão média: 87.31
# Geração: 260  Aptidão média: 88.54
# Geração: 261  Aptidão média: 89.68
# Geração: 262  Aptidão média: 87.92
# Geração: 263  Aptidão média: 79.85
# Geração: 264  Aptidão média: 81.23
# Geração: 265  Aptidão média: 78.15
# Geração: 266  Aptidão média: 83.7
# Geração: 267  Aptidão média: 89.36
# Geração: 268  Aptidão média: 83.29
# Geração: 269  Aptidão média: 89.94
# Geração: 270  Aptidão média: 89.91
# Geração: 271  Aptidão média: 89.1
# Geração: 272  Aptidão média: 87.79
# Geração: 273  Aptidão média: 83.12
# Geração: 274  Aptidão média: 90.21
# Geração: 275  Aptidão média: 85.16
# Geração: 276  Aptidão média: 85.97
# Geração: 277  Aptidão média: 86.24
# Geração: 278  Aptidão média: 91.05
# Geração: 279  Aptidão média: 88.14
# Geração: 280  Aptidão média: 88.2
# Geração: 281  Aptidão média: 83.57
# Geração: 282  Aptidão média: 79.43
# Geração: 283  Aptidão média: 91.09
# Geração: 284  Aptidão média: 94.0
# Geração: 285  Aptidão média: 91.66
# Geração: 286  Aptidão média: 87.33
# Geração: 287  Aptidão média: 93.38
# Geração: 288  Aptidão média: 85.39
# Geração: 289  Aptidão média: 89.94
# Geração: 290  Aptidão média: 82.58
# Geração: 291  Aptidão média: 77.81
# Geração: 292  Aptidão média: 89.39
# Geração: 293  Aptidão média: 81.91
# Geração: 294  Aptidão média: 86.22
# Geração: 295  Aptidão média: 87.54
# Geração: 296  Aptidão média: 92.35
# Geração: 297  Aptidão média: 88.65
# Geração: 298  Aptidão média: 96.54
# Geração: 299  Aptidão média: 99.11
# Geração: 300  Aptidão média: 98.33
# Geração: 301  Aptidão média: 98.51
# Geração: 302  Aptidão média: 97.99
# Geração: 303  Aptidão média: 99.2
# Geração: 304  Aptidão média: 98.88
# Geração: 305  Aptidão média: 100.82
# Geração: 306  Aptidão média: 99.38
# Geração: 307  Aptidão média: 99.44
# Geração: 308  Aptidão média: 99.51
# Geração: 309  Aptidão média: 88.59
# Geração: 310  Aptidão média: 64.22
# Geração: 311  Aptidão média: 91.06
# Geração: 312  Aptidão média: 83.81
# Geração: 313  Aptidão média: 82.44
# Geração: 314  Aptidão média: 83.09
# Geração: 315  Aptidão média: 92.14
# Geração: 316  Aptidão média: 100.39
# Geração: 317  Aptidão média: 89.55
# Geração: 318  Aptidão média: 86.52
# Geração: 319  Aptidão média: 88.79
# Geração: 320  Aptidão média: 102.36
# Geração: 321  Aptidão média: 103.05
# Geração: 322  Aptidão média: 106.53
# Geração: 323  Aptidão média: 105.61
# Geração: 324  Aptidão média: 105.2
# Geração: 325  Aptidão média: 105.65
# Geração: 326  Aptidão média: 105.24
# Geração: 327  Aptidão média: 106.64
# Geração: 328  Aptidão média: 106.1
# Geração: 329  Aptidão média: 106.24
# Geração: 330  Aptidão média: 98.63
# Geração: 331  Aptidão média: 105.7
# Geração: 332  Aptidão média: 101.8
# Geração: 333  Aptidão média: 101.57
# Geração: 334  Aptidão média: 105.02
# Geração: 335  Aptidão média: 97.83
# Geração: 336  Aptidão média: 103.94
# Geração: 337  Aptidão média: 104.32
# Geração: 338  Aptidão média: 104.99
# Geração: 339  Aptidão média: 100.42
# Geração: 340  Aptidão média: 99.98
# Geração: 341  Aptidão média: 104.93
# Geração: 342  Aptidão média: 100.79
# Geração: 343  Aptidão média: 103.65
# Geração: 344  Aptidão média: 101.86
# Geração: 345  Aptidão média: 104.54
# Geração: 346  Aptidão média: 106.6
# Geração: 347  Aptidão média: 103.08
# Geração: 348  Aptidão média: 105.4
# Geração: 349  Aptidão média: 105.85
# Geração: 350  Aptidão média: 101.88
# Geração: 351  Aptidão média: 95.89
# Geração: 352  Aptidão média: 86.66
# Geração: 353  Aptidão média: 99.63
# Geração: 354  Aptidão média: 103.96
# Geração: 355  Aptidão média: 99.71
# Geração: 356  Aptidão média: 105.95
# Geração: 357  Aptidão média: 100.69
# Geração: 358  Aptidão média: 101.14
# Geração: 359  Aptidão média: 83.4
# Geração: 360  Aptidão média: 99.74
# Geração: 361  Aptidão média: 104.21
# Geração: 362  Aptidão média: 106.32
# Geração: 363  Aptidão média: 105.7
# Geração: 364  Aptidão média: 104.44
# Geração: 365  Aptidão média: 106.02
# Geração: 366  Aptidão média: 105.51
# Geração: 367  Aptidão média: 103.5
# Geração: 368  Aptidão média: 106.73
# Geração: 369  Aptidão média: 105.84
# Geração: 370  Aptidão média: 102.13
# Geração: 371  Aptidão média: 90.97
# Geração: 372  Aptidão média: 99.99
# Geração: 373  Aptidão média: 102.86
# Geração: 374  Aptidão média: 102.21
# Geração: 375  Aptidão média: 105.12
# Geração: 376  Aptidão média: 101.35
# Geração: 377  Aptidão média: 105.41
# Geração: 378  Aptidão média: 105.77
# Geração: 379  Aptidão média: 102.89
# Geração: 380  Aptidão média: 103.0
# Geração: 381  Aptidão média: 100.5
# Geração: 382  Aptidão média: 99.68
# Geração: 383  Aptidão média: 106.05
# Geração: 384  Aptidão média: 101.91
# Geração: 385  Aptidão média: 106.27
# Geração: 386  Aptidão média: 105.56
# Geração: 387  Aptidão média: 103.09
# Geração: 388  Aptidão média: 104.74
# Geração: 389  Aptidão média: 100.69
# Geração: 390  Aptidão média: 101.9
# Geração: 391  Aptidão média: 103.47
# Geração: 392  Aptidão média: 101.89
# Geração: 393  Aptidão média: 101.54
# Geração: 394  Aptidão média: 103.51
# Geração: 395  Aptidão média: 97.42
# Geração: 396  Aptidão média: 103.44
# Geração: 397  Aptidão média: 106.19
# Geração: 398  Aptidão média: 97.57
# Geração: 399  Aptidão média: 83.56
# Geração: 400  Aptidão média: 100.57
# Geração: 401  Aptidão média: 104.61
# Geração: 402  Aptidão média: 105.53
# Geração: 403  Aptidão média: 106.17
# Geração: 404  Aptidão média: 104.95
# Geração: 405  Aptidão média: 104.45
# Geração: 406  Aptidão média: 106.72
# Geração: 407  Aptidão média: 99.89
# Geração: 408  Aptidão média: 100.59
# Geração: 409  Aptidão média: 101.55
# Geração: 410  Aptidão média: 104.12
# Geração: 411  Aptidão média: 102.63
# Geração: 412  Aptidão média: 102.05
# Geração: 413  Aptidão média: 102.9
# Geração: 414  Aptidão média: 103.07
# Geração: 415  Aptidão média: 102.17
# Geração: 416  Aptidão média: 106.66
# Geração: 417  Aptidão média: 104.44
# Geração: 418  Aptidão média: 106.12
# Geração: 419  Aptidão média: 105.92
# Geração: 420  Aptidão média: 103.89
# Geração: 421  Aptidão média: 103.02
# Geração: 422  Aptidão média: 102.4
# Geração: 423  Aptidão média: 94.53
# Geração: 424  Aptidão média: 105.93
# Geração: 425  Aptidão média: 104.55
# Geração: 426  Aptidão média: 102.78
# Geração: 427  Aptidão média: 95.97
# Geração: 428  Aptidão média: 93.28
# Geração: 429  Aptidão média: 94.3
# Geração: 430  Aptidão média: 103.61
# Geração: 431  Aptidão média: 97.81
# Geração: 432  Aptidão média: 41.92
# Geração: 433  Aptidão média: 71.46
# Geração: 434  Aptidão média: 46.93
# Geração: 435  Aptidão média: 30.48
# Geração: 436  Aptidão média: 87.65
# Geração: 437  Aptidão média: 106.09
# Geração: 438  Aptidão média: 102.59
# Geração: 439  Aptidão média: 104.11
# Geração: 440  Aptidão média: 104.38
# Geração: 441  Aptidão média: 101.97
# Geração: 442  Aptidão média: 99.94
# Geração: 443  Aptidão média: 103.1
# Geração: 444  Aptidão média: 104.69
# Geração: 445  Aptidão média: 103.92
# Geração: 446  Aptidão média: 98.34
# Geração: 447  Aptidão média: 99.36
# Geração: 448  Aptidão média: 97.95
# Geração: 449  Aptidão média: 103.67
# Geração: 450  Aptidão média: 103.42
# Geração: 451  Aptidão média: 99.56
# Geração: 452  Aptidão média: 104.77
# Geração: 453  Aptidão média: 105.94
# Geração: 454  Aptidão média: 97.94
# Geração: 455  Aptidão média: 105.84
# Geração: 456  Aptidão média: 102.0
# Geração: 457  Aptidão média: 103.41
# Geração: 458  Aptidão média: 101.17
# Geração: 459  Aptidão média: 101.36
# Geração: 460  Aptidão média: 102.95
# Geração: 461  Aptidão média: 104.68
# Geração: 462  Aptidão média: 105.96
# Geração: 463  Aptidão média: 99.48
# Geração: 464  Aptidão média: 106.77
# Geração: 465  Aptidão média: 99.71
# Geração: 466  Aptidão média: 89.65
# Geração: 467  Aptidão média: 102.67
# Geração: 468  Aptidão média: 100.47
# Geração: 469  Aptidão média: 103.01
# Geração: 470  Aptidão média: 103.05
# Geração: 471  Aptidão média: 104.14
# Geração: 472  Aptidão média: 101.09
# Geração: 473  Aptidão média: 99.94
# Geração: 474  Aptidão média: 99.4
# Geração: 475  Aptidão média: 105.54
# Geração: 476  Aptidão média: 105.7
# Geração: 477  Aptidão média: 105.38
# Geração: 478  Aptidão média: 102.34
# Geração: 479  Aptidão média: 104.28
# Geração: 480  Aptidão média: 106.38
# Geração: 481  Aptidão média: 106.31
# Geração: 482  Aptidão média: 103.22
# Geração: 483  Aptidão média: 105.09
# Geração: 484  Aptidão média: 104.12
# Geração: 485  Aptidão média: 98.85
# Geração: 486  Aptidão média: 106.31
# Geração: 487  Aptidão média: 105.42
# Geração: 488  Aptidão média: 101.43
# Geração: 489  Aptidão média: 106.48
# Geração: 490  Aptidão média: 105.78
# Geração: 491  Aptidão média: 104.33
# Geração: 492  Aptidão média: 100.46
# Geração: 493  Aptidão média: 105.17
# Geração: 494  Aptidão média: 105.69
# Geração: 495  Aptidão média: 98.58
# Geração: 496  Aptidão média: 103.63
# Geração: 497  Aptidão média: 96.64
# Geração: 498  Aptidão média: 106.36
# Geração: 499  Aptidão média: 106.62
# Geração: 500  Aptidão média: 103.48
# Itens: Arroz, Mapa, Papel Higiênico, Fósforo, Bússola, Protetor Solar, Colheres, Facas, Alicate, Band Aid, Mertiolate,
# Peso:  21
# Volume:  30
# Utilidae:  128
